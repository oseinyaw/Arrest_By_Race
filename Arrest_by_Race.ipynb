# %%
#Upload code from local drive
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ad5388d-9474-4f28-a336-5a513d2cd8ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ad5388d-9474-4f28-a336-5a513d2cd8ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
#import dataset
import io
df2 = pd.read_csv(io.BytesIO(uploaded['NYPD_Arrest_Data__Year_to_Date__20231219 (2).csv']))

# %%
df2
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0        261209118  01/01/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 1        262984267  02/03/2023    515     CONTROLLED SUBSTANCE,SALE 3  117.0
# 2        263664549  02/15/2023    105               STRANGULATION 1ST  106.0
# 3        261345231  01/04/2023    105               STRANGULATION 1ST  106.0
# 4        263536618  02/13/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# ...            ...         ...    ...                             ...    ...
# 170090   270955727  07/07/2023    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 170091   273117887  08/18/2023    681      CHILD, ENDANGERING WELFARE  233.0
# 170092   274301006  09/13/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 170093   269912233  06/15/2023    490    STOLEN PROPERTY 3,POSSESSION  232.0
# 170094   272045762  07/28/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
#
# ...

# %%
# Filtered out the data not needed for my hypothesis
df3=df2[['PERP_RACE','OFNS_DESC',]]
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb7def4813e7> in <cell line: 2>()
#       1 # Filtered out the data not needed for my hypothesis
# ----> 2 df3=df2[['PERP_RACE','OFNS_DESC', "Offense Category"]]
#       3 df3
#
# NameError: name 'df2' is not defined

# %%
# Groupby race by offense to get a summarized view
df4=df3.groupby(['PERP_RACE'])['OFNS_DESC'].count()
df4
# Out:
# PERP_RACE
# AMERICAN INDIAN/ALASKAN NATIVE      552
# ASIAN / PACIFIC ISLANDER           9066
# BLACK                             82041
# BLACK HISPANIC                    16501
# UNKNOWN                            2481
# WHITE                             16373
# WHITE HISPANIC                    43081
# Name: OFNS_DESC, dtype: int64

# %%
df3[df3['OFNS_DESC']=='FELONY ASSAULT']
# Out:
#              PERP_RACE       OFNS_DESC
# 0                BLACK  FELONY ASSAULT
# 2                WHITE  FELONY ASSAULT
# 3                BLACK  FELONY ASSAULT
# 4                BLACK  FELONY ASSAULT
# 5                BLACK  FELONY ASSAULT
# ...                ...             ...
# 169998  BLACK HISPANIC  FELONY ASSAULT
# 170030           BLACK  FELONY ASSAULT
# 170034           BLACK  FELONY ASSAULT
# 170044  BLACK HISPANIC  FELONY ASSAULT
# 170077  BLACK HISPANIC  FELONY ASSAULT
#
# [16030 rows x 2 columns]

# %%
df_FA=df3[df3['OFNS_DESC']=='FELONY ASSAULT']
df_FA
# Out:
#              PERP_RACE       OFNS_DESC
# 0                BLACK  FELONY ASSAULT
# 2                WHITE  FELONY ASSAULT
# 3                BLACK  FELONY ASSAULT
# 4                BLACK  FELONY ASSAULT
# 5                BLACK  FELONY ASSAULT
# ...                ...             ...
# 169998  BLACK HISPANIC  FELONY ASSAULT
# 170030           BLACK  FELONY ASSAULT
# 170034           BLACK  FELONY ASSAULT
# 170044  BLACK HISPANIC  FELONY ASSAULT
# 170077  BLACK HISPANIC  FELONY ASSAULT
#
# [16030 rows x 2 columns]

# %%
df_FAC=df_FA.groupby(['PERP_RACE'])['OFNS_DESC'].count()
df_FAC
# Out:
# PERP_RACE
# AMERICAN INDIAN/ALASKAN NATIVE      66
# ASIAN / PACIFIC ISLANDER          1010
# BLACK                             7907
# BLACK HISPANIC                    1445
# UNKNOWN                            243
# WHITE                             1158
# WHITE HISPANIC                    4201
# Name: OFNS_DESC, dtype: int64

# %%
#Visuilize the data for Assault by Race
df_FAC.plot(kind="bar")
# Out:
# <Axes: xlabel='PERP_RACE'>

# %%
df_FOR=df3[df3['OFNS_DESC']=='FORGERY']
df_FOR
# Out:
#              PERP_RACE OFNS_DESC
# 8                BLACK   FORGERY
# 21      WHITE HISPANIC   FORGERY
# 117              BLACK   FORGERY
# 119              BLACK   FORGERY
# 172     WHITE HISPANIC   FORGERY
# ...                ...       ...
# 169813  BLACK HISPANIC   FORGERY
# 169868           BLACK   FORGERY
# 169981           BLACK   FORGERY
# 170081           BLACK   FORGERY
# 170094           BLACK   FORGERY
#
# [2591 rows x 2 columns]

# %%
#Group by the race and crime
df_FORP=df_FOR.groupby(['PERP_RACE'])['OFNS_DESC'].count()
df_FOR.groupby(['PERP_RACE'])['OFNS_DESC'].count()
# Out:
# PERP_RACE
# AMERICAN INDIAN/ALASKAN NATIVE       5
# ASIAN / PACIFIC ISLANDER           154
# BLACK                             1371
# BLACK HISPANIC                     262
# UNKNOWN                             31
# WHITE                              128
# WHITE HISPANIC                     640
# Name: OFNS_DESC, dtype: int64

# %%
#Visualize the data
df_FORP.plot(kind='bar')
# Out:
# <Axes: xlabel='PERP_RACE'>

# %%
#Visually to the pie I believe the pie part give you more of a bird eye view of
df_FORP.plot(kind='pie')
#Population	White alone, percent	 37.5%
#Black or African American alone, percent(a)	 23.1%
#American Indian and Alaska Native alone, percent(a)	 0.6%
#Asian alone, percent(a)	 14.5%
# Out:
# <Axes: ylabel='OFNS_DESC'>

# %%
df2
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0        261209118  01/01/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 1        262984267  02/03/2023    515     CONTROLLED SUBSTANCE,SALE 3  117.0
# 2        263664549  02/15/2023    105               STRANGULATION 1ST  106.0
# 3        261345231  01/04/2023    105               STRANGULATION 1ST  106.0
# 4        263536618  02/13/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# ...            ...         ...    ...                             ...    ...
# 170090   270955727  07/07/2023    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 170091   273117887  08/18/2023    681      CHILD, ENDANGERING WELFARE  233.0
# 170092   274301006  09/13/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 170093   269912233  06/15/2023    490    STOLEN PROPERTY 3,POSSESSION  232.0
# 170094   272045762  07/28/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
#
# ...

# %%
dfAGE=df2[['OFNS_DESC','AGE_GROUP',]]
dfAGE
# Out:
#                             OFNS_DESC AGE_GROUP
# 0                      FELONY ASSAULT     45-64
# 1                     DANGEROUS DRUGS     25-44
# 2                      FELONY ASSAULT     25-44
# 3                      FELONY ASSAULT     25-44
# 4                      FELONY ASSAULT     25-44
# ...                               ...       ...
# 170090                        ROBBERY     25-44
# 170091                     SEX CRIMES     25-44
# 170092       OTHER TRAFFIC INFRACTION     25-44
# 170093  POSSESSION OF STOLEN PROPERTY     25-44
# 170094                        FORGERY     18-24
#
# [170095 rows x 2 columns]

# %%
dfAGEplot=dfAGE.groupby(['AGE_GROUP'])['OFNS_DESC'].count()
dfAGE.groupby(['AGE_GROUP'])['OFNS_DESC'].count()
dfseaborn=dfAGE.groupby(['AGE_GROUP'])['OFNS_DESC'].count()
#Not a good data setup or survying because 18-24 is only 6 years as opposed to 25-44 which is larger scope. Therefore you will have a numerically higher number. This would create a bias.

# %%
dfAGEplot.plot(kind='bar', x='Age', y='Amount')
# Out:
# <Axes: xlabel='AGE_GROUP'>

# %%
dfAGEplot.plot(kind='pie')
# Out:
# <Axes: ylabel='OFNS_DESC'>

# %%
#Did a little more deeper dive I wanted to learn alittle, 68 percent  of black ex convicts are re arrested after 3 years
#That also explain that a few are responisble for increase the recorded number of "black" percentage convicted
#Therefore we do make up a small percentage of the population (13 percent),
#But out of that 13 percent some are getting rearrested, which increase the count but not "different" individuals getting arrested
# The way we record data is important because it changes the narrative, can be used positively and negatively

# %%
df2
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0        261209118  01/01/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 1        262984267  02/03/2023    515     CONTROLLED SUBSTANCE,SALE 3  117.0
# 2        263664549  02/15/2023    105               STRANGULATION 1ST  106.0
# 3        261345231  01/04/2023    105               STRANGULATION 1ST  106.0
# 4        263536618  02/13/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# ...            ...         ...    ...                             ...    ...
# 170090   270955727  07/07/2023    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 170091   273117887  08/18/2023    681      CHILD, ENDANGERING WELFARE  233.0
# 170092   274301006  09/13/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 170093   269912233  06/15/2023    490    STOLEN PROPERTY 3,POSSESSION  232.0
# 170094   272045762  07/28/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
#
# ...

# %%
dfBLACK=df2[['PERP_RACE','OFNS_DESC']]
dfBLACK
# Out:
#              PERP_RACE                      OFNS_DESC
# 0                BLACK                 FELONY ASSAULT
# 1                BLACK                DANGEROUS DRUGS
# 2                WHITE                 FELONY ASSAULT
# 3                BLACK                 FELONY ASSAULT
# 4                BLACK                 FELONY ASSAULT
# ...                ...                            ...
# 170090           BLACK                        ROBBERY
# 170091           BLACK                     SEX CRIMES
# 170092  WHITE HISPANIC       OTHER TRAFFIC INFRACTION
# 170093           BLACK  POSSESSION OF STOLEN PROPERTY
# 170094           BLACK                        FORGERY
#
# [170095 rows x 2 columns]

# %%
dfBLACk_CRIME=dfBLACK[dfBLACK['PERP_RACE']=='BLACK']
dfBLACk_CRIME
# Out:
#        PERP_RACE                       OFNS_DESC
# 0          BLACK                  FELONY ASSAULT
# 1          BLACK                 DANGEROUS DRUGS
# 3          BLACK                  FELONY ASSAULT
# 4          BLACK                  FELONY ASSAULT
# 5          BLACK                  FELONY ASSAULT
# ...          ...                             ...
# 170088     BLACK  OTHER OFFENSES RELATED TO THEF
# 170090     BLACK                         ROBBERY
# 170091     BLACK                      SEX CRIMES
# 170093     BLACK   POSSESSION OF STOLEN PROPERTY
# 170094     BLACK                         FORGERY
#
# [82041 rows x 2 columns]

# %%
dfBLACk_CRIME.groupby(['OFNS_DESC'])['PERP_RACE'].count().sort_values(ascending=False)
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES            11733
# FELONY ASSAULT                           7907
# PETIT LARCENY                            7862
# MISCELLANEOUS PENAL LAW                  5476
# DANGEROUS DRUGS                          5402
# VEHICLE AND TRAFFIC LAWS                 4914
# ROBBERY                                  4801
# DANGEROUS WEAPONS                        4449
# CRIMINAL MISCHIEF & RELATED OF           3864
# GRAND LARCENY                            3683
# OFFENSES AGAINST PUBLIC ADMINI           2790
# OTHER OFFENSES RELATED TO THEF           2435
# BURGLARY                                 2230
# OFFENSES INVOLVING FRAUD                 1600
# OFF. AGNST PUB ORD SENSBLTY &            1583
# SEX CRIMES                               1472
# FORGERY                                  1371
# POSSESSION OF STOLEN PROPERTY            1222
# MURDER & NON-NEGL. MANSLAUGHTE            937
# OTHER TRAFFIC INFRACTION                  766
# ...

# %%
dfWHITE=dfBLACK[dfBLACK['PERP_RACE']=='WHITE']
dfWHITE
# Out:
#        PERP_RACE                     OFNS_DESC
# 2          WHITE                FELONY ASSAULT
# 10         WHITE                         ARSON
# 16         WHITE                FELONY ASSAULT
# 20         WHITE                          RAPE
# 24         WHITE                FELONY ASSAULT
# ...          ...                           ...
# 170049     WHITE  ASSAULT 3 & RELATED OFFENSES
# 170061     WHITE                 PETIT LARCENY
# 170068     WHITE                 PETIT LARCENY
# 170084     WHITE       MISCELLANEOUS PENAL LAW
# 170089     WHITE                 PETIT LARCENY
#
# [16373 rows x 2 columns]

# %%
dfWHITE.groupby(['OFNS_DESC'])['PERP_RACE'].count().sort_values(ascending=False)
# Out:
# OFNS_DESC
# PETIT LARCENY                           2705
# ASSAULT 3 & RELATED OFFENSES            2135
# MISCELLANEOUS PENAL LAW                 1397
# DANGEROUS DRUGS                         1366
# CRIMINAL MISCHIEF & RELATED OF          1176
# FELONY ASSAULT                          1158
# GRAND LARCENY                            914
# VEHICLE AND TRAFFIC LAWS                 667
# BURGLARY                                 535
# DANGEROUS WEAPONS                        495
# OFFENSES AGAINST PUBLIC ADMINI           445
# ROBBERY                                  415
# OFF. AGNST PUB ORD SENSBLTY &            310
# SEX CRIMES                               302
# OTHER OFFENSES RELATED TO THEF           295
# OFFENSES INVOLVING FRAUD                 251
# INTOXICATED & IMPAIRED DRIVING           235
# CRIMINAL TRESPASS                        183
# POSSESSION OF STOLEN PROPERTY            169
# FOR OTHER AUTHORITIES                    143
# OTHER TRAFFIC INFRACTION                 139
# ...
